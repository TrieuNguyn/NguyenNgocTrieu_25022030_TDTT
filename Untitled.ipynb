# %%
def mark(lst):
    dct = {}
    for e in lst:
        if dct.get(e,0)==0:
            dct[e] = 1
    return dct

lst = input().split()
for e in mark(lst):
    if mark(lst)[e] == 1:
        print(e)
# Out:
#   3 4 5 66 77 88 3 4 5 99
# 3
# 4
# 5
# 66
# 77
# 88
# 99
